# %%
import pandas as pd
import numpy as np

df = pd.read_csv("kearl_lake_cleaned (1).csv")

# %%
df
# Out:
#            lake                   parameter     source_file  \
# 0    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 1    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 2    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 3    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 4    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# ..          ...                         ...             ...
# 657  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 658  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 659  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 660  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 661  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
#
#       sampling_timestamp     sample_timestamp  measurement_value  \
# 0    2003-03-24 12:00:00  2003-03-24 12:00:00              0.400
# 1    2004-07-26 12:00:00  2004-07-26 11:00:00              0.267
# ...

# %%
rows_mg = df[df["unit_symbol"] == "mg/l"]

rows_mg
# Out:
#            lake                   parameter     source_file  \
# 93   kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 94   kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 95   kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 96   kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 97   kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# ..          ...                         ...             ...
# 657  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 658  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 659  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 660  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 661  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
#
#       sampling_timestamp     sample_timestamp  measurement_value  \
# 93   2000-09-27 12:00:00  2000-09-27 11:00:00              0.011
# 94   2001-09-13 12:00:00  2001-09-13 11:00:00              0.013
# ...

# %%
dfunits = df.copy()

dfunits["vanadium_total_recoverable"] = pd.to_numeric(
    dfunits["vanadium_total_recoverable"], errors="coerce"
)

condition = dfunits['unit_symbol'] == 'mg/l'
dfunits.loc[condition, 'vanadium_total_recoverable'] *= 1000
dfunits.loc[condition, 'unit_symbol'] = 'µg/l'

dfunits
# Out:
#            lake                   parameter     source_file  \
# 0    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 1    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 2    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 3    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 4    kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# ..          ...                         ...             ...
# 657  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 658  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 659  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 660  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
# 661  kearl_lake  vanadium_total_recoverable  KEARL LAKE.csv
#
#       sampling_timestamp     sample_timestamp  measurement_value  \
# 0    2003-03-24 12:00:00  2003-03-24 12:00:00              0.400
# 1    2004-07-26 12:00:00  2004-07-26 11:00:00              0.267
# ...

# %%
rows_mg = dfunits[dfunits["unit_symbol"] == "mg/l"]

rows_mg
# Out:
# Empty DataFrame
# Columns: [lake, parameter, source_file, sampling_timestamp, sample_timestamp, measurement_value, measurement_value_raw, site_name, station_name, depth, value_sign, unit_symbol, method, laboratory, sampling_number, sample_number, rdl, sample_location, sample_type, vanadium_total_recoverable]
# Index: []

# %%
df_clean = dfunits.drop(columns=[
    "parameter",
    "source_file",
    "sample_timestamp",
    "measurement_value_raw",
    "station_name",
    "method",
    "sampling_number",
    "sample_number",
    "sample_location",
    "sample_type"

])
df_clean
# Out:
#            lake   sampling_timestamp  measurement_value   site_name depth  \
# 0    kearl_lake  2003-03-24 12:00:00              0.400  KEARL LAKE   NaN
# 1    kearl_lake  2004-07-26 12:00:00              0.267  KEARL LAKE   NaN
# 2    kearl_lake  2004-08-24 15:05:00              0.257  KEARL LAKE   NaN
# 3    kearl_lake  2005-07-22 12:00:00              0.342  KEARL LAKE   NaN
# 4    kearl_lake  2005-08-30 08:55:00              0.251  KEARL LAKE   NaN
# ..          ...                  ...                ...         ...   ...
# 657  kearl_lake  2015-08-29 07:30:00              0.007  KEARL LAKE   NaN
# 658  kearl_lake  2015-08-29 07:30:00              0.795  KEARL LAKE   NaN
# 659  kearl_lake  2015-08-29 07:30:00              0.009  KEARL LAKE   NaN
# 660  kearl_lake  2016-08-26 11:45:00              0.881  KEARL LAKE   NaN
# 661  kearl_lake  2017-08-25 07:45:00              0.854  KEARL LAKE   NaN
#
#     value_sign unit_symbol                                         laboratory  \
# ...

# %%
header_indices = df_clean[df_clean['site_name'] == 'Site Name'].index.tolist()
print(header_indices)
print(len(header_indices))
# Out:
# [33, 65, 92, 139, 186, 233, 249, 263, 297, 329, 366, 440, 474, 506, 538, 572, 604, 638]
# 18

# %%
starts = [33, 65, 92, 139, 186, 233, 249, 263, 297, 329, 366, 440, 474, 506, 538, 572, 604, 638]

dfs = []

for i in range(len(starts)):
    
    start = starts[i]
    
    if i < len(starts) - 1:
        end = starts[i+1]
        df_split = df_clean.iloc[start:end]
    else:
        df_split = df_clean.iloc[start:]   # last section
    
    dfs.append(df_split)

# %%
#clean_dfs = []

for d in dfs:
    
    chem_name = d.iloc[0, -1]   # chemical name from header row
    
    d.rename(columns={d.columns[-1]: chem_name}, inplace=True)
    
    d.drop(index=d.index[0], inplace=True)  # remove header row
# Out:
# C:\Users\morsal.n\AppData\Local\Temp\ipykernel_35904\1715359265.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.rename(columns={d.columns[-1]: chem_name}, inplace=True)
# C:\Users\morsal.n\AppData\Local\Temp\ipykernel_35904\1715359265.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.drop(index=d.index[0], inplace=True)  # remove header row
# C:\Users\morsal.n\AppData\Local\Temp\ipykernel_35904\1715359265.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
"""for i, d in enumerate(clean_dfs):
    print(f"\nDataFrame {i}")
    print(d)"""
dfs[9].head()
# Out:
#            lake   sampling_timestamp  measurement_value   site_name depth  \
# 330  kearl_lake  2003-03-24 12:00:00               38.6  KEARL LAKE   NaN
# 331  kearl_lake  2004-07-26 12:00:00               17.6  KEARL LAKE   NaN
# 332  kearl_lake  2004-08-24 15:05:00               18.1  KEARL LAKE   NaN
# 333  kearl_lake  2005-07-22 12:00:00               15.4  KEARL LAKE   NaN
# 334  kearl_lake  2005-08-30 08:55:00               15.2  KEARL LAKE   NaN
#
#     value_sign unit_symbol                                    laboratory  rdl  \
# 330        NaN        µg/l                      Alberta Research Council  0.1
# 331        NaN        µg/l                      Alberta Research Council  0.1
# 332        NaN        µg/l  AITF-EAS (ENVIRONMENTAL ANALYTICAL SERVICES)  NaN
# 333        NaN        µg/l                      Alberta Research Council  0.1
# 334        NaN        µg/l  AITF-EAS (ENVIRONMENTAL ANALYTICAL SERVICES)  NaN
#
#      Calcium Total
# 330        38600.0
# ...

# %%
# Aluminum
dfs[12] = dfs[12].rename(columns={dfs[12].columns[-1]: "Aluminum Dissolved"})
aluminum_df = dfs[12][["sampling_timestamp", "Aluminum Dissolved"]]

dfs[11] = dfs[11].rename(columns={dfs[11].columns[-1]: "Aluminum Total Recoverable"})
aluminum_total_df = dfs[11][["sampling_timestamp", "Aluminum Total Recoverable"]]

# Calcium
dfs[10] = dfs[10].rename(columns={dfs[10].columns[-1]: "Calcium Dissolved"})
calcium_df = dfs[10][["sampling_timestamp", "Calcium Dissolved"]]

dfs[9] = dfs[9].rename(columns={dfs[9].columns[-1]: "Calcium Total"})
calcium_total_df = dfs[9][["sampling_timestamp", "Calcium Total"]]

# Copper
dfs[8] = dfs[8].rename(columns={dfs[8].columns[-1]: "Copper Dissolved"})
copper_df = dfs[8][["sampling_timestamp", "Copper Dissolved"]]

dfs[7] = dfs[7].rename(columns={dfs[7].columns[-1]: "Copper Total Recoverable"})
copper_total_df = dfs[7][["sampling_timestamp", "Copper Total Recoverable"]]

# Lead
dfs[13] = dfs[13].rename(columns={dfs[13].columns[-1]: "Lead Dissolved"})
lead_df = dfs[13][["sampling_timestamp", "Lead Dissolved"]]

dfs[14] = dfs[14].rename(columns={dfs[14].columns[-1]: "Lead Total Recoverable"})
lead_total_df = dfs[14][["sampling_timestamp", "Lead Total Recoverable"]]

# Nickel
dfs[15] = dfs[15].rename(columns={dfs[15].columns[-1]: "Nickel Dissolved"})
nickel_df = dfs[15][["sampling_timestamp", "Nickel Dissolved"]]

dfs[16] = dfs[16].rename(columns={dfs[16].columns[-1]: "Nickel Total Recoverable"})
nickel_total_df = dfs[16][["sampling_timestamp", "Nickel Total Recoverable"]]

# Nitrogen
dfs[17] = dfs[17].rename(columns={dfs[17].columns[-1]: "Nitrogen Dissolved"})
nitrogen_df = dfs[17][["sampling_timestamp", "Nitrogen Dissolved"]]

# Phosphorus
dfs[3] = dfs[3].rename(columns={dfs[3].columns[-1]: "Phosphorus Total Dissolved"})
phosphorus_df = dfs[3][["sampling_timestamp", "Phosphorus Total Dissolved"]]

dfs[2] = dfs[2].rename(columns={dfs[2].columns[-1]: "Phosphorus Total"})
phosphorus_total_df = dfs[2][["sampling_timestamp", "Phosphorus Total"]]

# Vanadium
dfs[0] = dfs[0].rename(columns={dfs[0].columns[-1]: "Vanadium Dissolved"})
vanadium_df = dfs[0][["sampling_timestamp", "Vanadium Dissolved"]]

# Turbidity
dfs[1] = dfs[1].rename(columns={dfs[1].columns[-1]: "Turbidity"})
turbidity_df = dfs[1][["sampling_timestamp", "Turbidity"]]

# pH
dfs[4] = dfs[4].rename(columns={dfs[4].columns[-1]: "pH"})
ph_df = dfs[4][["sampling_timestamp", "pH"]]

# Oxygen BOD
dfs[6] = dfs[6].rename(columns={dfs[6].columns[-1]: "OXYGEN BIOCHEMICAL DEMAND"})
oxygen_bod_df = dfs[6][["sampling_timestamp", "OXYGEN BIOCHEMICAL DEMAND"]]

dfs[5] = dfs[5].rename(columns={dfs[5].columns[-1]: "Oxygen dissolved % saturation"})
oxygen_sat_df = dfs[5][["sampling_timestamp", "Oxygen dissolved % saturation"]]

# %%
kearl_clean = pd.concat(
    [
         aluminum_df,
        aluminum_total_df,
        calcium_df,
        calcium_total_df,
        copper_df,
        copper_total_df,
        lead_df,
        lead_total_df,
        nickel_df,
        nickel_total_df,
        nitrogen_df,
        phosphorus_df,
        phosphorus_total_df,
        vanadium_df,
        turbidity_df,
        ph_df,
        oxygen_sat_df,
        oxygen_bod_df
    ],
    axis=0
)


kearl_clean["Site Name"] = "Kearl LAKE"
kearl_clean["Unit Symbol"] = "µg/l"

kearl_clean= kearl_clean.groupby("sampling_timestamp", as_index=False).first()

kearl_clean["sampling_timestamp"] = pd.to_datetime(
    kearl_clean["sampling_timestamp"], errors="coerce"
)

# %%
kearl_clean = kearl_clean.sort_values(by="sampling_timestamp")
kearl_clean
# Out:
#     sampling_timestamp  Aluminum Dissolved  Aluminum Total Recoverable  \
# 0  2000-09-27 12:00:00                 NaN                         NaN
# 1  2001-09-13 12:00:00                 NaN                         NaN
# 2  2002-09-04 12:00:00                 NaN                         NaN
# 3  2003-03-24 12:00:00               6.000                       19.40
# 4  2003-08-31 12:00:00                 NaN                         NaN
# 5  2004-06-17 14:30:00                 NaN                         NaN
# 6  2004-07-14 09:15:00                 NaN                         NaN
# 7  2004-07-26 12:00:00               2.120                       17.80
# 8  2004-08-24 15:05:00               0.940                       12.70
# 9  2004-09-25 13:10:00                 NaN                         NaN
# 10 2005-04-07 08:00:00                 NaN                         NaN
# 11 2005-05-26 12:00:00                 NaN                         NaN
# ...

# %%
kearl_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   sampling_timestamp             43 non-null     datetime64[ns]
#  1   Aluminum Dissolved             30 non-null     object
#  2   Aluminum Total Recoverable     32 non-null     object
#  3   Calcium Dissolved              43 non-null     object
#  4   Calcium Total                  30 non-null     object
#  5   Copper Dissolved               30 non-null     object
#  6   Copper Total Recoverable       32 non-null     object
#  7   Lead Dissolved                 30 non-null     object
#  8   Lead Total Recoverable         32 non-null     object
#  9   Nickel Dissolved               30 non-null     object
#  10  Nickel Total Recoverable       32 non-null     object
#  11  Nitrogen Dissolved             21 non-null     object
# ...

# %%
kearl_clean.to_csv("KearlLake_Data.csv", index= False)
